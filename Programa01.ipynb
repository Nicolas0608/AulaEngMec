# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicolas0608/AulaEngMec/blob/main/Programa01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importancia dos tipos de variaveis
a = 2.5
print(type(a))
b = 3.0
print(type(b))
soma = a + b
print(type(soma))
print(soma)
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# 5.5

# %%
num = int(input("digite valor inteiro: "))
print(type(num))
quoc = num//2
resto = num % 2
print(quoc)
print(resto)
# Out:
# digite valor inteiro: 9
# <class 'int'>
# 4
# 1

# %%
#Exemplo2

base = float(input("digite o valor da base do triangulo"))
altura = float(input("digite o valor da altura do triangulo"))
#calcular a area do triangulo
area = (base * altura)/2
#exibir a area calculada
print(f"A área do triângulo com base {base} e altura {altura} é {area}.")
# Fim do programa
# Out:
# digite o valor da base do triangulo10
# digite o valor da altura do triangulo10
# A área do triângulo com base 10.0 e altura 10.0 é 50.0.

# %%
P = float(input("Digite o valor em polegadas: "))
mm = P*25.4
print("O valor em polegadas convertido para milímetros =", mm)
# Out:
# Digite o valor em polegadas: 325
# O valor em polegadas convertido para milímetros = 8255.0

# %%
fahrenheit = float(input("Digite a temperatura em fahrenheit"))
celsius = (5/9) * (fahrenheit - 32)
print(f"A temperatura em celsius é {celsius:.2f}°C")
# Out:
# Digite a temperatura em fahrenheit158
# A temperatura em celsius é 70.00°C

# %%
import math # imports the math module

raio = float(input("Digite o raio da esfera em unidades de comprimento: "))
volume = (4/3) * math.pi * raio**3 # Changed r to raio
print(f"O volume da esfera com {raio} é {volume:.2f} unidades cúbicas. ")
# Out:
# Digite o raio da esfera em unidades de comprimento: 10
# O volume da esfera com 10.0 é 4188.79 unidades cúbicas.

# %%
import math # imports the math module

graus = float(input("digite o angulo em graus: "))
radianos = graus * (math.pi / 180)
print(f"o angulo de {graus} graus é igual a {radiano:.4f} radianos. ") # Changed 'radiano' to 'radianos'
# Out:
# digite o angulo em graus: 80
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-01f2d2780341> in <cell line: 5>()
#       3 graus = float(input("digite o angulo em graus: "))
#       4 radianos = graus * (math.pi / 180)
# ----> 5 print(f"o angulo de {graus} graus é igual a {radiano:.4f} radianos. ") # Changed 'radiano' to 'radianos'
#
# NameError: name 'radiano' is not defined

# %%
import math # imports the math module

graus = float(input("digite o angulo em graus: "))
radianos = graus * (math.pi/180)
print(f"o angulo de {graus} graus é igual a {radianos:.1f} radianos. ") # Changed 'radiano' to 'radianos'
# Out:
# digite o angulo em graus: 80
# o angulo de 80.0 graus é igual a 1.4 radianos.
